# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_auc_score,
    precision_recall_curve,
    roc_curve,
    auc
)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

np.random.seed(42)
tf.random.set_seed(42)



data = pd.read_csv(r"C:\Users\23adsb56\Downloads\creditcard.csv")

X = data.drop("Class", axis=1)
y = data["Class"]

print("Dataset shape:", data.shape)
print("Fraud ratio:", y.mean())


neg, pos = np.bincount(y)
total = neg + pos

class_weight = {
    0: total / (2 * neg),
    1: total / (2 * pos)
}

print("Class weights:", class_weight)


def build_dnn(input_dim, lr=1e-3):
    model = Sequential([
        Dense(128, activation='relu', input_dim=input_dim),
        BatchNormalization(),
        Dropout(0.3),

        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),

        Dense(32, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer=Adam(learning_rate=lr),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

def evaluate_model(model, X_test, y_test, title=""):
    y_prob = model.predict(X_test).ravel()
    y_pred = (y_prob >= 0.5).astype(int)

    print("\n", "="*50)
    print(title)
    print("Confusion Matrix")
    print(confusion_matrix(y_test, y_pred))
    print("\nClassification Report")
    print(classification_report(y_test, y_pred, digits=4))

    roc_auc = roc_auc_score(y_test, y_prob)
    precision, recall, _ = precision_recall_curve(y_test, y_prob)
    pr_auc = auc(recall, precision)

    print("ROC-AUC:", roc_auc)
    print("PR-AUC :", pr_auc)

    # ROC Curve
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    plt.figure()
    plt.plot(fpr, tpr, label=f"ROC-AUC = {roc_auc:.4f}")
    plt.plot([0,1],[0,1],'k--')
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"ROC Curve - {title}")
    plt.legend()
    plt.show()

    # Precision-Recall Curve
    plt.figure()
    plt.plot(recall, precision, label=f"PR-AUC = {pr_auc:.4f}")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.title(f"Precision-Recall Curve - {title}")
    plt.legend()
    plt.show()

    return roc_auc, pr_auc

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = build_dnn(X_train.shape[1])

history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=2048,
    class_weight=class_weight,
    verbose=1
)

plt.plot(history.history['loss'])
plt.title("Training Loss - Exp 1 (80-20)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

roc1, pr1 = evaluate_model(model, X_test, y_test, "Experiment 1 (80-20)")

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = build_dnn(X_train.shape[1])
model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=2048,
    class_weight=class_weight,
    verbose=1
)

roc2, pr2 = evaluate_model(model, X_test, y_test, "Experiment 2 (70-30)")


X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.25, stratify=y_temp, random_state=42
)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

model = build_dnn(X_train.shape[1])

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=2048,
    class_weight=class_weight,
    callbacks=[early_stop],
    verbose=1
)

plt.plot(history.history['loss'], label="Train")
plt.plot(history.history['val_loss'], label="Validation")
plt.title("Loss Curve - Exp 3 (60-20-20)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

roc3, pr3 = evaluate_model(model, X_test, y_test, "Experiment 3 (60-20-20)")

X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.15, stratify=y, random_state=42
)

X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.1765, stratify=y_temp, random_state=42
)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

model = build_dnn(X_train.shape[1])

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=2048,
    class_weight=class_weight,
    callbacks=[early_stop],
    verbose=1
)

roc4, pr4 = evaluate_model(model, X_test, y_test, "Experiment 4 (70-15-15)")

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

roc_scores = []
pr_scores = []

for fold, (train_idx, test_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    model = build_dnn(X_train.shape[1])
    model.fit(
        X_train, y_train,
        epochs=20,
        batch_size=2048,
        class_weight=class_weight,
        verbose=0
    )

    y_prob = model.predict(X_test).ravel()
    roc_scores.append(roc_auc_score(y_test, y_prob))
    precision, recall, _ = precision_recall_curve(y_test, y_prob)
    pr_scores.append(auc(recall, precision))

print("\n5-Fold Cross-Validation Results")
print("ROC-AUC Mean ± Std:", np.mean(roc_scores), np.std(roc_scores))
print("PR-AUC  Mean ± Std:", np.mean(pr_scores), np.std(pr_scores))
# Out:
# Dataset shape: (284807, 31)
# Fraud ratio: 0.001727485630620034
# Class weights: {0: np.float64(0.5008652375006595), 1: np.float64(289.4380081300813)}
# C:\Users\23adsb56\.conda\envs\61782323110056\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6325 - loss: 0.5617
# Epoch 2/20
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8527 - loss: 0.2855
# Epoch 3/20
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9238 - loss: 0.2108
# Epoch 4/20
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9458 - loss: 0.1964
# Epoch 5/20
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9564 - loss: 0.1738
# Epoch 6/20
# ...

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\23adsb56\.conda\envs\61782323110056\python.exe

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.20.0
